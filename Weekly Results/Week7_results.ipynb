# %%
import simstudy

# %% [markdown]
# ## STA - compare with Theoretical plot from equation 32
# ### Q = 2, K = 1

# %%
simstudy.simulate_sic_oscillations(50, 1)
# Out:
# Time for simulation:
# 85.95241355895996

# %% [markdown]
# ### Q = 3, K = 1

# %%
simstudy.simulate_sic_oscillations(50, 1)
# Out:
# Time for simulation:
# 90.39735007286072

# %% [markdown]
# ### Q = 4, K = 1

# %%
simstudy.simulate_sic_oscillations(50, 1, 4)
# Out:
# Time for simulation:
# 85.5249993801117

# %% [markdown]
# ### Q = 2, K = 2

# %%
simstudy.simulate_sic_oscillations(50, 2, 2)
# Out:
# Time for simulation:
# 53.50862956047058

# %% [markdown]
# ### Q = 3, K = 2

# %%
simstudy.simulate_sic_oscillations(50, 2, 3)
# Out:
# Time for simulation:
# 57.879154443740845

# %% [markdown]
# ### Q = 4, K = 2

# %%
simstudy.simulate_sic_oscillations(50, 2, 4)
# Out:
# Time for simulation:
# 58.82769417762756

# %% [markdown]
# ### Q = 2, K = 3

# %%
simstudy.simulate_sic_oscillations(50, 3, 2)
# Out:
# Time for simulation:
# 40.767388105392456

# %% [markdown]
# ### Q = 2, K = 4

# %%
simstudy.simulate_sic_oscillations(50, 4, 2)
# Out:
# Time for simulation:
# 37.681082010269165

# %% [markdown]
# ### Q = 2, K = 8

# %%
simstudy.simulate_sic_oscillations(50, 8, 2)
# Out:
# Time for simulation:
# 21.360239505767822

# %% [markdown]
# ### Q = 2, K = 12

# %%
simstudy.simulate_sic_oscillations(50, 12, 2)
# Out:
# Time for simulation:
# 17.320534706115723
