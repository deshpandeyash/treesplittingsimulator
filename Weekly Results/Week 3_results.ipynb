# %% [markdown]
# ## All SICTA Results

# %% [markdown]
# ### SICTA Dynamic- Free Access

# %%
import simstudy
simstudy.simulate_simple_tree_dynamic_multiple_runs(modified=True, unisplit=False, sic=True)
# Out:
# Optimum Throughput = 0.7000000000000002

# %% [markdown]
# ### SICTA Dynamic- Gated Access

# %%
import simstudy
simstudy.simulate_simple_tree_dynamic_multiple_runs_gated(modified=True, unisplit=False, sic=True)

# %% [markdown]
# ### SICTA Static Multiple Access
#
# No of collided packets- 1000

# %%
import simstudy
simstudy.simulate_simple_tree_static_multpile_runs(modified=True, unisplit=False, sic=True)
# Out:
# Mean Throughput is = 0.6933368317160528
